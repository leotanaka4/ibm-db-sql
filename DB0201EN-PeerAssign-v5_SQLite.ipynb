# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a SQLIte database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Census Data</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Public Schools</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be loaded into SQLite DB.
# We will create three tables in as under:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**
#
# Let us now load the ipython-sql  extension and establish a connection with the database
#
# * Here you will be loading the csv files into the pandas Dataframe and then loading the data into the above mentioned sqlite tables.
#
# * Next you will be connecting to the sqlite database  **FinalDB**.
#
# Refer to the previous lab for hints .
#
# <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing_SQLite.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %%
import pandas as pd
import sqlite3

# criar a conexão ao banco de dados SQLite
conn = sqlite3.connect('FinalDB.db')

# liste os nomes dos seus arquivos csv
arquivos_csv = ['ChicagoCensusData.csv', 'ChicagoPublicSchools.csv', 'ChicagoCrimeData.csv']

# Liste os nomes das tabelas SQL
nomes_tabelas = ['CENSUS_DATA', 'CHICAGO_PUBLIC_SCHOOLS','CHICAGO_CRIME_DATA']

for arquivo, nome_tabela in zip(arquivos_csv, nomes_tabelas):
    # carregar o csv em um dataframe pandas
    df = pd.read_csv(arquivo)

    # inserir o dataframe como uma tabela no banco de dados SQLite
    df.to_sql(nome_tabela, conn, if_exists='replace', index=False)

# fechar a conexão ao banco de dados
conn.close()

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import pandas as pd
import sqlite3

# criar a conexão ao banco de dados SQLite
conn = sqlite3.connect('FinalDB.db')

# liste os nomes dos seus arquivos csv
arquivos_csv = ['ChicagoCensusData.csv', 'ChicagoPublicSchools.csv', 'ChicagoCrimeData.csv']

# Liste os nomes das tabelas SQL
nomes_tabelas = ['CENSUS_DATA', 'CHICAGO_PUBLIC_SCHOOLS','CHICAGO_CRIME_DATA']

for arquivo, nome_tabela in zip(arquivos_csv, nomes_tabelas):
    # carregar o csv em um dataframe pandas
    df = pd.read_csv(arquivo)

    # inserir o dataframe como uma tabela no banco de dados SQLite
    df.to_sql(nome_tabela, conn, if_exists='replace', index=False)

# fechar a conexão ao banco de dados
conn.close()

# %%
# %sql sqlite:///FinalDB.db

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(*) FROM CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(533,)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %sql SELECT COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME, PER_CAPITA_INCOME FROM CENSUS_DATA WHERE PER_CAPITA_INCOME < 11000;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(26.0, 'West Garfield Park', 10934),
#  (30.0, 'South Lawndale', 10402),
#  (37.0, 'Fuller Park', 10432),
#  (54.0, 'Riverdale', 8201)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?(children are not considered minors for the purposes of crime analysis)

# %%
# %sql SELECT CASE_NUMBER FROM CHICAGO_CRIME_DATA WHERE DESCRIPTION LIKE '%MINOR%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('HL266884',), ('HK238408',)]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA WHERE PRIMARY_TYPE = 'KIDNAPPING';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(5276766, 'HN144152', '2007-01-26', '050XX W VAN BUREN ST', '1792', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER', 'STREET', 0, 0, 1533, 15, 29.0, 25.0, '20', 1143050.0, 1897546.0, 2007, 41.87490841, -87.75024931, '(41.874908413, -87.750249307)')]

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %%sql SELECT PRIMARY_TYPE, LOCATION_DESCRIPTION from CHICAGO_CRIME_DATA
# WHERE LOCATION_DESCRIPTION LIKE '%SCHOOL%'
# GROUP BY PRIMARY_TYPE, LOCATION_DESCRIPTION;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ASSAULT', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PUBLIC, BUILDING')]

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for each type of school.

# %%
# %%sql SELECT [Elementary, Middle, or High School], AVG(SAFETY_SCORE) FROM CHICAGO_PUBLIC_SCHOOLS
# GROUP BY [Elementary, Middle, or High School];
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('ES', 49.52038369304557), ('HS', 49.62352941176471), ('MS', 48.0)]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %%sql SELECT COMMUNITY_AREA_NAME, PERCENT_HOUSEHOLDS_BELOW_POVERTY
# FROM CENSUS_DATA
# ORDER BY PERCENT_HOUSEHOLDS_BELOW_POVERTY DESC LIMIT 5;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 56.5),
#  ('Fuller Park', 51.2),
#  ('Englewood', 46.6),
#  ('North Lawndale', 43.1),
#  ('East Garfield Park', 42.4)]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %%
# %%sql SELECT COMMUNITY_AREA_NUMBER, COUNT(*) AS FREQUENCY FROM CHICAGO_CRIME_DATA
# GROUP BY COMMUNITY_AREA_NUMBER
# ORDER BY FREQUENCY DESC LIMIT 1;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [(25.0, 43)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %%sql SELECT COMMUNITY_AREA_NAME, HARDSHIP_INDEX
# FROM CENSUS_DATA
# WHERE HARDSHIP_INDEX = (SELECT MAX(HARDSHIP_INDEX) FROM CENSUS_DATA);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Riverdale', 98.0)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %%sql SELECT COMMUNITY_AREA_NAME
# FROM CENSUS_DATA
# WHERE COMMUNITY_AREA_NUMBER = (SELECT COMMUNITY_AREA_NUMBER
#                                FROM CHICAGO_CRIME_DATA
#                                GROUP BY COMMUNITY_AREA_NUMBER
#                                ORDER BY COUNT(*) DESC LIMIT 1);
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Austin',)]

# %%
# %%sql SELECT CPS.NAME_OF_SCHOOL, CPS.COMMUNITY_AREA_NAME, CPS.AVERAGE_STUDENT_ATTENDANCE,
# CD.HARDSHIP_INDEX
# FROM CHICAGO_PUBLIC_SCHOOLS CPS
# INNER JOIN CENSUS_DATA CD
# ON CPS.COMMUNITY_AREA_NUMBER = CD.COMMUNITY_AREA_NUMBER
# WHERE CD.HARDSHIP_INDEX = 98;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('George Washington Carver Military Academy High School', 'RIVERDALE', '91.60%', 98.0),
#  ('George Washington Carver Primary School', 'RIVERDALE', '90.90%', 98.0),
#  ('Ira F Aldridge Elementary School', 'RIVERDALE', '92.90%', 98.0),
#  ('William E B Dubois Elementary School', 'RIVERDALE', '93.30%', 98.0)]

# %%
# %%sql SELECT CCD.LOCATION_DESCRIPTION, CCD.CASE_NUMBER, CCD.PRIMARY_TYPE,
# CD.COMMUNITY_AREA_NAME
# FROM CHICAGO_CRIME_DATA CCD
# INNER JOIN CENSUS_DATA CD
# ON CCD.COMMUNITY_AREA_NUMBER = CD.COMMUNITY_AREA_NUMBER
# WHERE CCD.LOCATION_DESCRIPTION LIKE '%SCHOOL%';
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('SCHOOL, PUBLIC, GROUNDS', 'HL353697', 'BATTERY', 'South Shore'),
#  ('SCHOOL, PUBLIC, BUILDING', 'HL725506', 'BATTERY', 'Lincoln Square'),
#  ('SCHOOL, PUBLIC, BUILDING', 'HP716225', 'BATTERY', 'Douglas'),
#  ('SCHOOL, PUBLIC, BUILDING', 'HH639427', 'BATTERY', 'Austin'),
#  ('SCHOOL, PUBLIC, GROUNDS', 'JA460432', 'BATTERY', 'Ashburn'),
#  ('SCHOOL, PUBLIC, GROUNDS', 'HS200939', 'CRIMINAL DAMAGE', 'Austin'),
#  ('SCHOOL, PUBLIC, GROUNDS', 'HK577020', 'NARCOTICS', 'Rogers Park'),
#  ('SCHOOL, PUBLIC, BUILDING', 'HS305355', 'NARCOTICS', 'Brighton Park'),
#  ('SCHOOL, PUBLIC, GROUNDS', 'HT315369', 'ASSAULT', 'East Garfield Park'),
#  ('SCHOOL, PUBLIC, GROUNDS', 'HR585012', 'CRIMINAL TRESPASS', 'Ashburn')]

# %%
# %%sql CREATE VIEW CPS (SCHOOL_NAME, SAFETY_RATING, FAMILY_RATING,
# ENVIRONMENT_RATING, INSTRUCTION_RATING, LEADERS_RATING, TEACHERS_RATING ) AS
# SELECT NAME_OF_SCHOOL, SAFETY_ICON, FAMILY_INVOLVEMENT_ICON, ENVIRONMENT_ICON,
# INSTRUCTION_ICON, LEADERS_ICON, TEACHERS_ICON
# FROM CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) table CPS already exists
# [SQL: CREATE VIEW CPS (SCHOOL_NAME, SAFETY_RATING, FAMILY_RATING,
# ENVIRONMENT_RATING, INSTRUCTION_RATING, LEADERS_RATING, TEACHERS_RATING ) AS
# SELECT NAME_OF_SCHOOL, SAFETY_ICON, FAMILY_INVOLVEMENT_ICON, ENVIRONMENT_ICON,
# INSTRUCTION_ICON, LEADERS_ICON, TEACHERS_ICON
# FROM CHICAGO_PUBLIC_SCHOOLS;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql SELECT * FROM CPS;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Abraham Lincoln Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 'Average', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('Adlai E Stevenson Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Agustin Lara Elementary Academy', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Air Force Academy High School', 'Average', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Albany Park Multicultural Academy', 'Strong', 'Weak', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Albert G Lane Technical High School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Albert R Sabin Elementary Magnet School', 'Strong', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Alcott High School for the Humanities', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Alessandro Volta Elementary School', 'Average', 'Strong', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Alexander Graham Bell Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Alexander Graham Elementary School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Alexander Hamilton Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Alexander von Humboldt Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Alex Haley Elementary Academy', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Alfred David Kohn Elementary School', 'Very Weak', 'Weak', 'Weak', 'Very Weak', 'Weak', 'Very Weak'),
#  ('Alfred Nobel Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Alice L Barnard Computer Math & Science Center Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Al Raby High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ambrose Plamondon Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Amelia Earhart Options for Knowledge Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Ames Middle School', 'Weak', 'Very Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Amos Alonzo Stagg Elementary School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Ana Roque de Duprey Elementary School', 'Average', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Andrew Carnegie Elementary School', 'Average', 'Average', 'Weak', 'Strong', 'Weak', 'Weak'),
#  ('Andrew Jackson Elementary Language Academy', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Anna R. Langford Community Academy', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Annie Keller Elementary Gifted Magnet School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('A.N. Pritzker School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Anthony Overton Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Ariel Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Arna Wendell Bontemps Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Arnold Mireles Elementary Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Arthur A Libby Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Arthur Dixon Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Arthur E Canty Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Arthur R Ashe Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Asa Philip Randolph Elementary School', 'Very Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ashburn Community Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Augustus H Burley Elementary School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Austin Business and Entrepreneurship Academy High School', 'Weak', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Austin O Sexton Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Austin Polytechnical Academy High School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Avalon Park Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('Barbara Vick Early Childhood & Family Center', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Belmont-Cragin Elementary School', 'Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Benito Juarez Community Academy High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Benjamin Banneker Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Benjamin E Mays Elementary Academy', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Bernhard Moos Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Betsy Ross Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Beulah Shoesmith Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Blair Early Childhood Center', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Bret Harte Elementary School', 'Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Brian Piccolo Elementary Specialty School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Brighton Park Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Bronzeville Scholastic Academy High School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('Burnham Elementary Inclusive Academy', 'Strong', 'Strong', 'Very Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('Burnside Elementary Scholastic Academy', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Calmeca Academy of Fine Arts and Dual Language', 'Average', 'Strong', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Carl Schurz High School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Carl von Linne Elementary School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Carrie Jacobs Bond Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Carroll-Rosenwald Specialty Elementary School', 'Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Carter G Woodson South Elementary School', 'Weak', 'Weak', 'Very Weak', 'Very Weak', 'Weak', 'Average'),
#  ('Cesar E Chavez Multicultural Academic Center Elementary School', 'Average', 'Average', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Charles Allen Prosser Career Academy High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Charles Evans Hughes Elementary School', 'Average', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('Charles Gates Dawes Elementary School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Charles G Hammond Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Charles H Wacker Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Charles Kozminski Elementary Community Academy', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Charles N Holden Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Charles P Caldwell Academy of Math & Science Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Charles P Steinmetz Academic Centre High School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Charles R Darwin Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Charles R Henderson Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Charles S Brownell Elementary School', 'Weak', 'Very Weak', 'Strong', 'Very Strong', 'Weak', 'Very Weak'),
#  ('Charles S Deneen Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Charles Sumner  Math & Science Community Acad Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Charles W Earle Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Chicago Academy Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Chicago Academy High School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Chicago High School for Agricultural Sciences', 'Very Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Chicago Military Academy High School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Chicago Vocational Career Academy High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Christian Ebinger Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('Christian Fenger Academy High School', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Christopher Columbus Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Clara Barton Elementary School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Claremont Academy Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Collins Academy High School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Columbia Explorers Elementary Academy', 'Average', 'Strong', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Countee Cullen Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Crispus Attucks Elementary School', 'Average', 'Strong', 'Strong', 'Average', 'Weak', 'Very Strong'),
#  ('Crown Community Academy of Fine Arts Center Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Cyrus H McCormick Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Daniel Boone Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Daniel C Beard Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Daniel Hale Williams Prep School of Medicine', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Daniel J Corkery Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Daniel R Cameron Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Daniel S Wentworth Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Daniel Webster Elementary School', 'Average', 'Average', 'Very Strong', 'Strong', 'Weak', 'Average'),
#  ('David G Farragut Career Academy High School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('DeVry University Advantage Academy High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Dewey Elementary Academy of Fine Arts', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('DeWitt Clinton Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Disney II Magnet School', 'NDA', 'Very Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Donald Morrill Math & Science Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Douglas Taylor Elementary School', 'Weak', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Dr Jorge Prieto Math and Science', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Dr  Martin Luther King  Jr  College Prep High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Dumas Technology Academy', 'Very Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Dunne Technology Academy', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Durkin Park Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Dvorak Technology Academy', 'Average', 'Weak', 'Strong', 'Strong', 'Weak', 'Very Weak'),
#  ('Dyett High School', 'Weak', 'Very Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Edgar Allan Poe Elementary Classical School', 'Very Strong', 'Weak', 'Strong', 'Very Strong', 'Weak', 'Average'),
#  ('Edgebrook Elementary School', 'Very Strong', 'Very Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Edison Park Elementary School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Edmond Burke Elementary School', 'Very Weak', 'NDA', 'Very Weak', 'Weak', 'Weak', 'NDA'),
#  ('Edward A Bouchet Math & Science Academy Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Edward Beasley Elementary Magnet Academic Center', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Edward C Delano Elementary School', 'Weak', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('Edward Coles Elementary Language Academy', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Edward Everett Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Edward Jenner Elementary Academy of the Arts', 'Average', 'Weak', 'Strong', 'Average', 'Weak', 'Weak'),
#  ('Edward K Ellington Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Edward N Hurley Elementary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Edward Tilden Career Community Academy High School', 'Weak', 'Average', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Edward White Elementary Career Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Edwin G Foreman High School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Elaine O Goodlow Elementary Magnet School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Elihu Yale Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Eli Whitney Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Elizabeth H Sutherland Elementary School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Elizabeth Peabody Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Eliza Chappell Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Ella Flagg Young Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ellen H Richards Career Academy High School', 'Weak', 'Weak', 'Weak', 'Very Weak', 'Weak', 'Weak'),
#  ('Ellen Mitchell Elementary School', 'Very Strong', 'Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Emil G Hirsch Metropolitan High School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Emiliano Zapata Elementary Academy', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Emmett Louis Till Math and Science Academy', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Enrico Fermi Elementary School', 'Weak', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Enrico Tonti Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Eric Solorio Academy High School', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Ernst Prussing Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Esmond Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Eugene Field Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Very Weak'),
#  ('Everett McKinley Dirksen Elementary School', 'Average', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Evergreen Academy Middle School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Fairfield Elementary Academy', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Federico Garcia Lorca Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Very Strong'),
#  ('Wilma Rudolph Elementary Learning Center', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Ferdinand Peck Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Fernwood Elementary School', 'Weak', 'Weak', 'Very Weak', 'Average', 'Weak', 'Average'),
#  ('Florence B Price Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Florence Nightingale Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Fort Dearborn Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Foster Park Elementary School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Francisco I Madero Middle School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Francis M McKay Elementary School', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Francis Parkman Elementary School', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Francis Scott Key Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Francis W Parker Elementary Community Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Frank I Bennett Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Frank L Gillespie Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Franklin Elementary Fine Arts Center', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', 'Average', 'Weak', 'Weak', 'Average', 'Weak', 'Very Weak'),
#  ('Frank W Reilly Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Franz Peter Schubert Elementary School', 'NDA', 'Weak', 'NDA', 'NDA', 'Weak', 'Weak'),
#  ('Frazier Prospective IB Magnet Elementary School', 'Strong', 'Average', 'Very Strong', 'Strong', 'Weak', 'Average'),
#  ('Frederic Chopin Elementary School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Frederick A Douglass Academy High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Frederick Funston Elementary School', 'Very Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Frederick Stock Elementary School', 'NDA', 'Very Strong', 'NDA', 'NDA', 'Weak', 'Very Strong'),
#  ('Friedrich Ludwig Jahn Elementary School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Friedrich W von Steuben Metropolitan Science High School', 'Strong', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Gage Park High School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Galileo Math & Science Scholastic Academy Elementary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Garrett A Morgan Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Genevieve Melody Elementary School', 'Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('George Armstrong International Studies Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('George B McClellan Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('George B Swift Elementary Specialty School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('George F Cassell Elementary School', 'Strong', 'Strong', 'Average', 'Weak', 'Weak', 'Strong'),
#  ('George H Corliss High School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('George Leland Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('George Manierre Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('George M Pullman Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('George Rogers Clark Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('George Washington Carver Military Academy High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('George Washington Carver Primary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('George Washington Elementary School', 'Average', 'Strong', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('George Washington High School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('George W Curtis Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('George Westinghouse High School', 'Strong', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Strong'),
#  ('George W Tilton Elementary School', 'Very Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Gerald Delgado Kanoon Elementary Magnet School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Graeme Stewart Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Granville T Woods Math & Science Academy Elementary School', 'Weak', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Greater Lawndale High School For Social Justice', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Grover Cleveland Elementary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Guglielmo Marconi Elementary Community Academy', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Gurdon S Hubbard High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Gwendolyn Brooks College Preparatory Academy High School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Hannah G Solomon Elementary School', 'Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Hanson Park Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Harold Washington Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Harriet Beecher Stowe Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Harriet E Sayre Elementary Language Academy', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Hawthorne Elementary Scholastic Academy', 'Very Strong', 'Very Strong', 'Strong', 'Average', 'Weak', 'Very Strong'),
#  ('Helen M Hefferan Elementary School', 'Weak', 'Weak', 'Weak', 'Strong', 'Weak', 'Average'),
#  ('Helen Peirce International Studies Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Helge A Haugan Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Henry Clay Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Henry D Lloyd Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Henry H Nash Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Henry O Tanner Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Henry R Clissold Elementary School', 'Average', 'Strong', 'Weak', 'Strong', 'Weak', 'Average'),
#  ('High School of Leadership at South Shore', 'NDA', 'Weak', 'NDA', 'NDA', 'Weak', 'Weak'),
#  ('Hiram H Belding Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Hope College Preparatory High School', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Horace Greeley Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Horace Mann Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Horatio May Elementary Community Academy', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Hyde Park Academy High School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Hyman G Rickover Naval Academy High School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Ida B Wells Preparatory Elementary Academy', 'Average', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Ignance Paderewski Elementary Learning Academy', 'Weak', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Infinity Math Science and Technology High School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Inter-American Elementary Magnet School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ira F Aldridge Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Irene C. Hernandez Middle School for the Advancement of Science', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Irma C Ruiz Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Irvin C Mollison Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ("Isabelle C O'Keeffe Elementary School", 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Jackie Robinson Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Jacob Beidler Elementary School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Jacqueline B Vaughn Occupational High School', 'Average', 'Strong', 'Weak', 'Weak', 'Weak', 'Strong'),
#  ('James B Farnsworth Elementary School', 'Average', 'Strong', 'Average', 'Weak', 'Weak', 'Average'),
#  ('James B McPherson Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('James E McDade Elementary Classical School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('James G Blaine Elementary School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('James Hedges Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James Madison Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James Monroe Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James N Thorp Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('James Otis Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Average', 'Weak', 'Very Strong'),
#  ('James R Doolittle Jr Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('James Russell Lowell Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('James Shields Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('James Wadsworth Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('James Ward Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('James Weldon Johnson Elementary School', 'Strong', 'Weak', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Jane Addams Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Jane A Neil Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Jean Baptiste Beaubien Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Jean D Lafayette Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Strong'),
#  ('Jensen Elementary Scholastic Academy', 'Weak', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Jesse Owens Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Jesse Sherwood Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Johann W von Goethe Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('John A Walsh Elementary School', 'Strong', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('John Barry Elementary School', 'Weak', 'Average', 'Strong', 'Very Strong', 'Weak', 'Average'),
#  ('John B Drake Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('John B Murphy Elementary School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('John Calhoun North Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Very Strong'),
#  ('John C Burroughs Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('John C Coonley Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Weak', 'Weak', 'Average'),
#  ('John C Dore Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('John Charles Haines Elementary School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('John D Shoop Math-Science Technical Academy Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('John F Eberhart Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('John Fiske Elementary School', 'Very Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('John F Kennedy High School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('John Foster Dulles Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('John Greenleaf Whittier Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('John Hancock College Preparatory High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('John Harvard Elementary School of Excellence', 'Average', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('John Hay Elementary Community Academy', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('John H Hamline Elementary School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('John H Kinzie Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('John H Vanderpoel Elementary Magnet School', 'Strong', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('John J Audubon Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('John J Pershing Elementary Humanities Magnet', 'NDA', 'Very Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('John L Marsh Elementary School', 'Strong', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('John Marshall Metropolitan High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('John M Harlan Community Academy High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('John Milton Gregory Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('John M Smyth Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Johnnie Colemon Elementary Academy', 'Strong', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('John Palmer Elementary School', 'Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('John P Altgeld Elementary School', 'Average', 'Weak', 'Strong', 'Average', 'Weak', 'Weak'),
#  ('John Spry Elementary Community School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('John T McCutcheon Elementary School', 'Average', 'Weak', 'Strong', 'Average', 'Weak', 'Average'),
#  ('John T Pirie Fine Arts & Academic Center Elementary School', 'Weak', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('John W Cook Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('John W Garvy Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('John Whistler Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Jonathan Burr Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Strong'),
#  ('Jonathan Y Scammon Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Jordan Elementary Community School', 'Strong', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('Jose De Diego Elementary Community Academy', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Josefa Ortiz De Dominguez Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Joseph Brennemann Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph E Gary Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('Josephine C Locke Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph Jungman Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph Kellman Corporate Community Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Joseph Lovett Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Joseph Stockton Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Joseph Warren Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Joshua D Kershaw Elementary School', 'Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('Josiah Pickard Elementary School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Joyce Kilmer Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Julia C Lathrop Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Julia Ward Howe Elementary School of Excellence', 'Strong', 'Average', 'Very Strong', 'Strong', 'Weak', 'Strong'),
#  ('Kate S Buckingham Special Education Center', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Kate S Kellogg Elementary School', 'Strong', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Kelvyn Park High School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Kenwood Academy High School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Lake View High School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Langston Hughes Elementary School', 'Weak', 'Average', 'Very Weak', 'Weak', 'Weak', 'Average'),
#  ('LaSalle Elementary Language Academy', 'Very Strong', 'Strong', 'Strong', 'Average', 'Weak', 'Average'),
#  ('LaSalle II Magnet Elementary School', 'Strong', 'Very Strong', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Laughlin Falconer Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Laura S Ward Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Lawndale Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Lazaro Cardenas Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Leif Ericson Elementary Scholastic Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Lenart Elementary Regional Gifted Center', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Leslie Lewis Elementary School', 'Weak', 'Weak', 'Weak', 'Strong', 'Weak', 'Average'),
#  ('Lincoln Park High School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Lionel Hampton Fine & Performing Arts Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Little Village Elementary School', 'Average', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Logandale Middle School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Lorenz Brentano Math & Science Academy Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Louis A Agassiz Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Louisa May Alcott Elementary School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Louis Armstrong Math & Science Elementary School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Louis Nettelhorst Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Louis Pasteur Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Ludwig Van Beethoven Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ("Luke O'Toole Elementary School", 'Very Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Luther Burbank Elementary School', 'Weak', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Lyman A Budlong Elementary School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Lyman Trumbull Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Mahalia Jackson Elementary School', 'Weak', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Mancel Talcott Elementary School', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Manley Career Academy High School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Manuel Perez Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Marcus Moziah Garvey Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Mariano Azuela Elementary School', 'Average', 'Very Strong', 'Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Maria Saucedo Elementary Scholastic Academy', 'Strong', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Marie Sklodowska Curie Metropolitan High School', 'Average', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Marine Military Math and Science Academy', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Mark Sheridan Elementary Math & Science Academy', 'Strong', 'Average', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('Mark Skinner Elementary School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Mark Twain Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Marquette Elementary School', 'Very Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Martha Ruggles Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Martin A Ryerson Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Marvin Camras Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Very Strong'),
#  ('Mary E Courtenay Elementary Language Arts Center', 'Very Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Mary E McDowell Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Average'),
#  ('Mary Gage Peterson Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Mary Lyon Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Mary Mapes Dodge Elementary Renaissance Academy', 'Average', 'Strong', 'Strong', 'Strong', 'Weak', 'Very Strong'),
#  ('Mary McLeod Bethune Elementary School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Mason High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Matthew A Henson Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Matthew Gallistel Elementary Language Academy', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Medgar Evers Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Melville W Fuller Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Michael Faraday Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Michael M Byrne Elementary School', 'Strong', 'Strong', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Michele Clark Academic Prep Magnet High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Mildred I Lavizzo Elementary School', 'Very Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Milton Brunson Math & Science Specialty Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Minnie Mars Jamieson Elementary School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Miriam G Canter Middle School', 'Average', 'Average', 'Weak', 'Weak', 'Weak', 'Strong'),
#  ('Morgan Park High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Morton School of Excellence', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Very Strong'),
#  ('Moses Montefiore Special Elementary School', 'Weak', 'NDA', 'Average', 'Very Weak', 'Weak', 'NDA'),
#  ('Mount Greenwood Elementary School', 'Very Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Mount Vernon Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Very Weak'),
#  ('Multicultural Academy of Scholarship', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Myra Bradwell Communications Arts & Sciences Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Average'),
#  ('Nathanael Greene Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Nathan Hale Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Nathaniel Pope Elementary School', 'Average', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Nathan R Goldblatt Elementary School', 'Average', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Nathan S Davis Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('National Teachers Elementary Academy', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Neal F Simeon Career Academy High School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Near North Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('New Field Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('New Millennium High School of Health at Bowen', 'Very Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('Newton Bateman Elementary School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Nicholas Senn High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Nicholson Technology Academy', 'Average', 'Weak', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Ninos Heroes Elementary Academic Center', 'Weak', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Norman A Bridge Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('North-Grand High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('North River Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Northside College Preparatory High School', 'Very Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Percy L Julian High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Northside Learning Center High School', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Weak', 'Very Strong'),
#  ('Northwest Middle School', 'Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Norwood Park Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Ogden International High School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Ole A Thorp Elementary Scholastic Academy', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('Oliver S Westcott Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Oliver Wendell Holmes Elementary School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Oriole Park Elementary School', 'Very Strong', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('Orozco Fine Arts & Sciences Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Orr Academy High School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Orville T Bright Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Oscar DePriest Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Oscar F Mayer Elementary School', 'Strong', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Pablo Casals Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Park Manor Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Parkside Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Patrick Henry Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Paul Cuffe Math-Science Technology Academy Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Very Strong'),
#  ('Paul Laurence Dunbar Career Academy High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Paul Revere Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Paul Robeson High School', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Perkins Bass Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Pershing West Middle School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Peter A Reinberg Elementary School', 'Strong', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Peter Cooper Elementary Dual Language Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Philip Rogers Elementary School', 'Very Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Phillip D Armour Elementary School', 'Weak', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Phillip Murray Elementary Language Academy', 'Strong', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Phobe Apperson Hearst Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Phoenix Military Academy High School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Pilsen Elementary Community Academy', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Portage Park Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Pulaski International Academy Elmentary School', 'Strong', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Rachel Carson Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Ralph H Metcalfe Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Ravenswood Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Ray Graham Training Center High School', 'Very Strong', 'Very Strong', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Richard Edwards Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Richard Henry Lee Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Richard J Daley Elementary Academy', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Average'),
#  ('Richard J Oglesby Elementary School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Richard T Crane Technical Preparatory High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Richard Yates Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Roald Amundsen High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Robert A Black Magnet Elementary School', 'Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Robert Emmet Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Robert Fulton Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('Robert Healy Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Robert H Lawrence Elementary School', 'Very Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Robert L Grimes Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Robert Lindblom Math & Science Academy High School', 'Strong', 'NDA', 'Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Robert Nathaniel Dett Elementary School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Roberto Clemente Community Academy High School', 'Average', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Rodolfo Lozano Bilingual & International Center Elementary School', 'Average', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Roger C Sullivan High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Ronald Brown Elementary Community Academy', 'Weak', 'Weak', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Ronald E McNair Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Rosario Castellanos Elementary School', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Roswell B Mason Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Rudyard Kipling Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Rueben Salazar Elementary Bilingual Center', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Rufus M Hitch Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Salmon P Chase Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Samuel Gompers Fine Arts Options Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Sauganash Elementary School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Scott Joplin Elementary School', 'Weak', 'Weak', 'Average', 'Average', 'Weak', 'Weak'),
#  ('Sharon Christa McAuliffe Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Sidney Sawyer Elementary School', 'Average', 'Weak', 'Average', 'Weak', 'Weak', 'Weak'),
#  ('Simon Guggenheim Elementary School', 'Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('Sir Miles Davis Magnet Elementary Academy', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Skinner North', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Socorro Sandoval Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Songhai Elementary Learning Institute', 'Very Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('South Loop Elementary School', 'Very Strong', 'Strong', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('South Shore Fine Arts Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Southside Occupational Academy High School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Spencer Technology Academy', 'Weak', 'Average', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Spry Community Links High School', 'Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('Stephen Decatur Classical Elementary School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Stephen F Gale Elementary Community Academy', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('Stephen K Hayt Elementary School', 'Strong', 'Strong', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Stephen T Mather High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('Stone Elementary Scholastic Academy', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Suder Montessori Magnet Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Talman Elementary School', 'Very Strong', 'Very Strong', 'Very Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('Tarkington School of Excellence Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('TEAM Englewood Community Academy High School', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Telpochcalli Elementary School', 'Average', 'Average', 'Very Weak', 'Weak', 'Weak', 'Strong'),
#  ('Theodore Herzl Elementary School', 'Average', 'NDA', 'Average', 'Strong', 'Weak', 'NDA'),
#  ('Theodore Roosevelt High School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Theophilus Schmid Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Thomas A Edison Regional Gifted Center Elementary School', 'Very Strong', 'NDA', 'Strong', 'Average', 'Weak', 'NDA'),
#  ('Thomas A Hendricks Elementary Community Academy', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Thomas Chalmers Specialty Elementary School', 'Weak', 'Strong', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('Thomas Drummond Elementary School', 'Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Thomas Hoyne Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Strong'),
#  ('Thomas J Higgins Elementary Community Academy', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Thomas J Waters Elementary School', 'Very Strong', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Thomas Kelly High School', 'Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Average'),
#  ('Thurgood Marshall Middle School', 'Weak', 'NDA', 'Very Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('Turner-Drew Elementary Language Academy', 'Average', 'Average', 'Average', 'Average', 'Weak', 'Strong'),
#  ('Uplift Community High School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Velma F Thomas Early Childhood Center', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Victor Herbert Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Virgil Grissom Elementary School', 'Strong', 'Strong', 'Average', 'Strong', 'Weak', 'Very Strong'),
#  ('VOISE Academy High School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Walt Disney Magnet Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Walter L Newberry Math & Science Academy Elementary School', 'Strong', 'Strong', 'Average', 'Strong', 'Weak', 'Average'),
#  ('Walter Payton College Preparatory High School', 'Very Strong', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('Walter Q Gresham Elementary School', 'Weak', 'Average', 'Very Weak', 'Very Weak', 'Weak', 'Average'),
#  ('Walter Reed Elementary School', 'Weak', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('Walter S Christopher Elementary School', 'NDA', 'Average', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Washington D Smyser Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Washington Irving Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('Wells Community Academy High School', 'Average', 'Average', 'Average', 'Weak', 'Weak', 'Average'),
#  ('Wendell E Green Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('Wendell Phillips Academy High School', 'NDA', 'Strong', 'NDA', 'NDA', 'Weak', 'Strong'),
#  ('Wendell Smith Elementary School', 'Weak', 'Weak', 'Very Weak', 'Very Weak', 'Weak', 'Weak'),
#  ('West Park Elementary Academy', 'Weak', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('West Pullman Elementary School', 'Weak', 'Average', 'Average', 'Average', 'Weak', 'Average'),
#  ('West Ridge Elementary School', 'Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Whitney M Young Magnet High School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Wildwood Elementary School', 'Very Strong', 'Very Strong', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('Willa Cather Elementary School', 'Strong', 'Strong', 'Strong', 'Very Strong', 'Weak', 'Very Strong'),
#  ('William A Hinton Elementary School', 'Very Weak', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('William Bishop Owen Scholastic Academy Elementary School', 'Average', 'Strong', 'Weak', 'Average', 'Weak', 'Average'),
#  ('William B Ogden Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('William C Goudy Elementary School', 'Strong', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('William C Reavis Math & Science Specialty Elementary School', 'Average', 'Very Weak', 'Weak', 'Weak', 'Weak', 'Very Weak'),
#  ('William E B Dubois Elementary School', 'Average', 'NDA', 'Weak', 'Average', 'Weak', 'NDA'),
#  ('William E Dever Elementary School', 'Strong', 'Strong', 'Strong', 'Strong', 'Weak', 'Weak'),
#  ('William F Finkl Elementary School', 'Average', 'Strong', 'Average', 'Average', 'Weak', 'Average'),
#  ('William G Hibbard Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('William H Brown Elementary School', 'Weak', 'Strong', 'Average', 'Strong', 'Weak', 'Strong'),
#  ('William H King Elementary School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William Howard Taft High School', 'Strong', 'NDA', 'Weak', 'Weak', 'Weak', 'NDA'),
#  ('William H Prescott Elementary School', 'Very Strong', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('William H Ray Elementary School', 'Strong', 'NDA', 'Weak', 'Very Weak', 'Weak', 'NDA'),
#  ('William H Ryder Math & Science Specialty Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William H Seward Communication Arts Academy Elementary School', 'Average', 'Average', 'Weak', 'Average', 'Weak', 'Strong'),
#  ('William J Bogan High School', 'Weak', 'NDA', 'Very Weak', 'Weak', 'Weak', 'NDA'),
#  ('William J & Charles H Mayo Elementary School', 'Average', 'Average', 'Strong', 'Strong', 'Weak', 'Average'),
#  ('William J Onahan Elementary School', 'Strong', 'Average', 'Weak', 'Weak', 'Weak', 'Weak'),
#  ('William Jones College Preparatory High School', 'Very Strong', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('William K New Sullivan Elementary School', 'Weak', 'Average', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('William Penn Elementary School', 'Strong', 'NDA', 'Very Strong', 'Very Strong', 'Weak', 'NDA'),
#  ('William P Gray Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('William P Nixon Elementary School', 'Average', 'NDA', 'Strong', 'Strong', 'Weak', 'NDA'),
#  ('William Rainey Harper High School', 'Weak', 'Weak', 'Weak', 'Average', 'Weak', 'Weak'),
#  ('Williams Multiplex Elementary School', 'NDA', 'NDA', 'NDA', 'NDA', 'Weak', 'NDA'),
#  ('Williams Preparatory Academy Middle School', 'Average', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William T Sherman Elementary School', 'Weak', 'NDA', 'Average', 'Average', 'Weak', 'NDA'),
#  ('William W Carter Elementary School', 'Very Weak', 'Average', 'Weak', 'Weak', 'Weak', 'Strong'),
#  ('Wolfgang A Mozart Elementary School', 'Average', 'NDA', 'Average', 'Weak', 'Weak', 'NDA'),
#  ('Woodlawn Community Elementary School', 'Strong', 'NDA', 'Very Strong', 'Strong', 'Weak', 'NDA'),
#  ('World Language Academy High School', 'Average', 'Weak', 'Average', 'Average', 'Weak', 'Average')]

# %%
# %sql SELECT SCHOOL_NAME, LEADERS_RATING FROM CPS;
# Out:
#  * sqlite:///FinalDB.db
# Done.
# [('Abraham Lincoln Elementary School', 'Weak'),
#  ('Adam Clayton Powell Paideia Community Academy Elementary School', 'Weak'),
#  ('Adlai E Stevenson Elementary School', 'Weak'),
#  ('Agustin Lara Elementary Academy', 'Weak'),
#  ('Air Force Academy High School', 'Weak'),
#  ('Albany Park Multicultural Academy', 'Weak'),
#  ('Albert G Lane Technical High School', 'Weak'),
#  ('Albert R Sabin Elementary Magnet School', 'Weak'),
#  ('Alcott High School for the Humanities', 'Weak'),
#  ('Alessandro Volta Elementary School', 'Weak'),
#  ('Alexander Graham Bell Elementary School', 'Weak'),
#  ('Alexander Graham Elementary School', 'Weak'),
#  ('Alexander Hamilton Elementary School', 'Weak'),
#  ('Alexander von Humboldt Elementary School', 'Weak'),
#  ('Alex Haley Elementary Academy', 'Weak'),
#  ('Alfred David Kohn Elementary School', 'Weak'),
#  ('Alfred Nobel Elementary School', 'Weak'),
#  ('Alice L Barnard Computer Math & Science Center Elementary School', 'Weak'),
#  ('Al Raby High School', 'Weak'),
#  ('Ambrose Plamondon Elementary School', 'Weak'),
#  ('Amelia Earhart Options for Knowledge Elementary School', 'Weak'),
#  ('Ames Middle School', 'Weak'),
#  ('Amos Alonzo Stagg Elementary School', 'Weak'),
#  ('Ana Roque de Duprey Elementary School', 'Weak'),
#  ('Andrew Carnegie Elementary School', 'Weak'),
#  ('Andrew Jackson Elementary Language Academy', 'Weak'),
#  ('Anna R. Langford Community Academy', 'Weak'),
#  ('Annie Keller Elementary Gifted Magnet School', 'Weak'),
#  ('A.N. Pritzker School', 'Weak'),
#  ('Anthony Overton Elementary School', 'Weak'),
#  ('Ariel Elementary Community Academy', 'Weak'),
#  ('Arna Wendell Bontemps Elementary School', 'Weak'),
#  ('Arnold Mireles Elementary Academy', 'Weak'),
#  ('Arthur A Libby Elementary School', 'Weak'),
#  ('Arthur Dixon Elementary School', 'Weak'),
#  ('Arthur E Canty Elementary School', 'Weak'),
#  ('Arthur R Ashe Elementary School', 'Weak'),
#  ('Asa Philip Randolph Elementary School', 'Weak'),
#  ('Ashburn Community Elementary School', 'Weak'),
#  ('Augustus H Burley Elementary School', 'Weak'),
#  ('Austin Business and Entrepreneurship Academy High School', 'Weak'),
#  ('Austin O Sexton Elementary School', 'Weak'),
#  ('Austin Polytechnical Academy High School', 'Weak'),
#  ('Avalon Park Elementary School', 'Weak'),
#  ('Barbara Vick Early Childhood & Family Center', 'Weak'),
#  ('Belmont-Cragin Elementary School', 'Weak'),
#  ('Benito Juarez Community Academy High School', 'Weak'),
#  ('Benjamin Banneker Elementary School', 'Weak'),
#  ('Benjamin E Mays Elementary Academy', 'Weak'),
#  ('Bernhard Moos Elementary School', 'Weak'),
#  ('Betsy Ross Elementary School', 'Weak'),
#  ('Beulah Shoesmith Elementary School', 'Weak'),
#  ('Blair Early Childhood Center', 'Weak'),
#  ('Bret Harte Elementary School', 'Weak'),
#  ('Brian Piccolo Elementary Specialty School', 'Weak'),
#  ('Brighton Park Elementary School', 'Weak'),
#  ('Bronzeville Scholastic Academy High School', 'Weak'),
#  ('Burnham Elementary Inclusive Academy', 'Weak'),
#  ('Burnside Elementary Scholastic Academy', 'Weak'),
#  ('Calmeca Academy of Fine Arts and Dual Language', 'Weak'),
#  ('Carl Schurz High School', 'Weak'),
#  ('Carl von Linne Elementary School', 'Weak'),
#  ('Carrie Jacobs Bond Elementary School', 'Weak'),
#  ('Carroll-Rosenwald Specialty Elementary School', 'Weak'),
#  ('Carter G Woodson South Elementary School', 'Weak'),
#  ('Cesar E Chavez Multicultural Academic Center Elementary School', 'Weak'),
#  ('Charles Allen Prosser Career Academy High School', 'Weak'),
#  ('Charles Evans Hughes Elementary School', 'Weak'),
#  ('Charles Gates Dawes Elementary School', 'Weak'),
#  ('Charles G Hammond Elementary School', 'Weak'),
#  ('Charles H Wacker Elementary School', 'Weak'),
#  ('Charles Kozminski Elementary Community Academy', 'Weak'),
#  ('Charles N Holden Elementary School', 'Weak'),
#  ('Charles P Caldwell Academy of Math & Science Elementary School', 'Weak'),
#  ('Charles P Steinmetz Academic Centre High School', 'Weak'),
#  ('Charles R Darwin Elementary School', 'Weak'),
#  ('Charles R Henderson Elementary School', 'Weak'),
#  ('Charles S Brownell Elementary School', 'Weak'),
#  ('Charles S Deneen Elementary School', 'Weak'),
#  ('Charles Sumner  Math & Science Community Acad Elementary School', 'Weak'),
#  ('Charles W Earle Elementary School', 'Weak'),
#  ('Chicago Academy Elementary School', 'Weak'),
#  ('Chicago Academy High School', 'Weak'),
#  ('Chicago High School for Agricultural Sciences', 'Weak'),
#  ('Chicago Military Academy High School', 'Weak'),
#  ('Chicago Vocational Career Academy High School', 'Weak'),
#  ('Christian Ebinger Elementary School', 'Weak'),
#  ('Christian Fenger Academy High School', 'Weak'),
#  ('Christopher Columbus Elementary School', 'Weak'),
#  ('Clara Barton Elementary School', 'Weak'),
#  ('Claremont Academy Elementary School', 'Weak'),
#  ('Collins Academy High School', 'Weak'),
#  ('Columbia Explorers Elementary Academy', 'Weak'),
#  ('Countee Cullen Elementary School', 'Weak'),
#  ('Crispus Attucks Elementary School', 'Weak'),
#  ('Crown Community Academy of Fine Arts Center Elementary School', 'Weak'),
#  ('Cyrus H McCormick Elementary School', 'Weak'),
#  ('Daniel Boone Elementary School', 'Weak'),
#  ('Daniel C Beard Elementary School', 'Weak'),
#  ('Daniel Hale Williams Prep School of Medicine', 'Weak'),
#  ('Daniel J Corkery Elementary School', 'Weak'),
#  ('Daniel R Cameron Elementary School', 'Weak'),
#  ('Daniel S Wentworth Elementary School', 'Weak'),
#  ('Daniel Webster Elementary School', 'Weak'),
#  ('David G Farragut Career Academy High School', 'Weak'),
#  ('DeVry University Advantage Academy High School', 'Weak'),
#  ('Dewey Elementary Academy of Fine Arts', 'Weak'),
#  ('DeWitt Clinton Elementary School', 'Weak'),
#  ('Disney II Magnet School', 'Weak'),
#  ('Donald Morrill Math & Science Elementary School', 'Weak'),
#  ('Douglas Taylor Elementary School', 'Weak'),
#  ('Dr Jorge Prieto Math and Science', 'Weak'),
#  ('Dr  Martin Luther King  Jr  College Prep High School', 'Weak'),
#  ('Dumas Technology Academy', 'Weak'),
#  ('Dunne Technology Academy', 'Weak'),
#  ('Durkin Park Elementary School', 'Weak'),
#  ('Dvorak Technology Academy', 'Weak'),
#  ('Dyett High School', 'Weak'),
#  ('Edgar Allan Poe Elementary Classical School', 'Weak'),
#  ('Edgebrook Elementary School', 'Weak'),
#  ('Edison Park Elementary School', 'Weak'),
#  ('Edmond Burke Elementary School', 'Weak'),
#  ('Edward A Bouchet Math & Science Academy Elementary School', 'Weak'),
#  ('Edward Beasley Elementary Magnet Academic Center', 'Weak'),
#  ('Edward C Delano Elementary School', 'Weak'),
#  ('Edward Coles Elementary Language Academy', 'Weak'),
#  ('Edward Everett Elementary School', 'Weak'),
#  ('Edward Jenner Elementary Academy of the Arts', 'Weak'),
#  ('Edward K Ellington Elementary School', 'Weak'),
#  ('Edward N Hurley Elementary School', 'Weak'),
#  ('Edward Tilden Career Community Academy High School', 'Weak'),
#  ('Edward White Elementary Career Academy', 'Weak'),
#  ('Edwin G Foreman High School', 'Weak'),
#  ('Elaine O Goodlow Elementary Magnet School', 'Weak'),
#  ('Elihu Yale Elementary School', 'Weak'),
#  ('Eli Whitney Elementary School', 'Weak'),
#  ('Elizabeth H Sutherland Elementary School', 'Weak'),
#  ('Elizabeth Peabody Elementary School', 'Weak'),
#  ('Eliza Chappell Elementary School', 'Weak'),
#  ('Ella Flagg Young Elementary School', 'Weak'),
#  ('Ellen H Richards Career Academy High School', 'Weak'),
#  ('Ellen Mitchell Elementary School', 'Weak'),
#  ('Emil G Hirsch Metropolitan High School', 'Weak'),
#  ('Emiliano Zapata Elementary Academy', 'Weak'),
#  ('Emmett Louis Till Math and Science Academy', 'Weak'),
#  ('Enrico Fermi Elementary School', 'Weak'),
#  ('Enrico Tonti Elementary School', 'Weak'),
#  ('Eric Solorio Academy High School', 'Weak'),
#  ('Ernst Prussing Elementary School', 'Weak'),
#  ('Esmond Elementary School', 'Weak'),
#  ('Eugene Field Elementary School', 'Weak'),
#  ('Everett McKinley Dirksen Elementary School', 'Weak'),
#  ('Evergreen Academy Middle School', 'Weak'),
#  ('Fairfield Elementary Academy', 'Weak'),
#  ('Federico Garcia Lorca Elementary School', 'Weak'),
#  ('Wilma Rudolph Elementary Learning Center', 'Weak'),
#  ('Ferdinand Peck Elementary School', 'Weak'),
#  ('Fernwood Elementary School', 'Weak'),
#  ('Florence B Price Elementary School', 'Weak'),
#  ('Florence Nightingale Elementary School', 'Weak'),
#  ('Fort Dearborn Elementary School', 'Weak'),
#  ('Foster Park Elementary School', 'Weak'),
#  ('Francisco I Madero Middle School', 'Weak'),
#  ('Francis M McKay Elementary School', 'Weak'),
#  ('Francis Parkman Elementary School', 'Weak'),
#  ('Francis Scott Key Elementary School', 'Weak'),
#  ('Francis W Parker Elementary Community Academy', 'Weak'),
#  ('Frank I Bennett Elementary School', 'Weak'),
#  ('Frank L Gillespie Elementary School', 'Weak'),
#  ('Franklin Elementary Fine Arts Center', 'Weak'),
#  ('Frank W Gunsaulus Elementary Scholastic Academy', 'Weak'),
#  ('Frank W Reilly Elementary School', 'Weak'),
#  ('Franz Peter Schubert Elementary School', 'Weak'),
#  ('Frazier Prospective IB Magnet Elementary School', 'Weak'),
#  ('Frederic Chopin Elementary School', 'Weak'),
#  ('Frederick A Douglass Academy High School', 'Weak'),
#  ('Frederick Funston Elementary School', 'Weak'),
#  ('Frederick Stock Elementary School', 'Weak'),
#  ('Friedrich Ludwig Jahn Elementary School', 'Weak'),
#  ('Friedrich W von Steuben Metropolitan Science High School', 'Weak'),
#  ('Gage Park High School', 'Weak'),
#  ('Galileo Math & Science Scholastic Academy Elementary School', 'Weak'),
#  ('Garrett A Morgan Elementary School', 'Weak'),
#  ('Genevieve Melody Elementary School', 'Weak'),
#  ('George Armstrong International Studies Elementary School', 'Weak'),
#  ('George B McClellan Elementary School', 'Weak'),
#  ('George B Swift Elementary Specialty School', 'Weak'),
#  ('George F Cassell Elementary School', 'Weak'),
#  ('George H Corliss High School', 'Weak'),
#  ('George Leland Elementary School', 'Weak'),
#  ('George Manierre Elementary School', 'Weak'),
#  ('George M Pullman Elementary School', 'Weak'),
#  ('George Rogers Clark Elementary School', 'Weak'),
#  ('George Washington Carver Military Academy High School', 'Weak'),
#  ('George Washington Carver Primary School', 'Weak'),
#  ('George Washington Elementary School', 'Weak'),
#  ('George Washington High School', 'Weak'),
#  ('George W Curtis Elementary School', 'Weak'),
#  ('George Westinghouse High School', 'Weak'),
#  ('George W Tilton Elementary School', 'Weak'),
#  ('Gerald Delgado Kanoon Elementary Magnet School', 'Weak'),
#  ('Graeme Stewart Elementary School', 'Weak'),
#  ('Granville T Woods Math & Science Academy Elementary School', 'Weak'),
#  ('Greater Lawndale High School For Social Justice', 'Weak'),
#  ('Grover Cleveland Elementary School', 'Weak'),
#  ('Guglielmo Marconi Elementary Community Academy', 'Weak'),
#  ('Gurdon S Hubbard High School', 'Weak'),
#  ('Gwendolyn Brooks College Preparatory Academy High School', 'Weak'),
#  ('Hannah G Solomon Elementary School', 'Weak'),
#  ('Hanson Park Elementary School', 'Weak'),
#  ('Harold Washington Elementary School', 'Weak'),
#  ('Harriet Beecher Stowe Elementary School', 'Weak'),
#  ('Harriet E Sayre Elementary Language Academy', 'Weak'),
#  ('Hawthorne Elementary Scholastic Academy', 'Weak'),
#  ('Helen M Hefferan Elementary School', 'Weak'),
#  ('Helen Peirce International Studies Elementary School', 'Weak'),
#  ('Helge A Haugan Elementary School', 'Weak'),
#  ('Henry Clay Elementary School', 'Weak'),
#  ('Henry D Lloyd Elementary School', 'Weak'),
#  ('Henry H Nash Elementary School', 'Weak'),
#  ('Henry O Tanner Elementary School', 'Weak'),
#  ('Henry R Clissold Elementary School', 'Weak'),
#  ('High School of Leadership at South Shore', 'Weak'),
#  ('Hiram H Belding Elementary School', 'Weak'),
#  ('Hope College Preparatory High School', 'Weak'),
#  ('Horace Greeley Elementary School', 'Weak'),
#  ('Horace Mann Elementary School', 'Weak'),
#  ('Horatio May Elementary Community Academy', 'Weak'),
#  ('Hyde Park Academy High School', 'Weak'),
#  ('Hyman G Rickover Naval Academy High School', 'Weak'),
#  ('Ida B Wells Preparatory Elementary Academy', 'Weak'),
#  ('Ignance Paderewski Elementary Learning Academy', 'Weak'),
#  ('Infinity Math Science and Technology High School', 'Weak'),
#  ('Inter-American Elementary Magnet School', 'Weak'),
#  ('Ira F Aldridge Elementary School', 'Weak'),
#  ('Irene C. Hernandez Middle School for the Advancement of Science', 'Weak'),
#  ('Irma C Ruiz Elementary School', 'Weak'),
#  ('Irvin C Mollison Elementary School', 'Weak'),
#  ("Isabelle C O'Keeffe Elementary School", 'Weak'),
#  ('Jackie Robinson Elementary School', 'Weak'),
#  ('Jacob Beidler Elementary School', 'Weak'),
#  ('Jacqueline B Vaughn Occupational High School', 'Weak'),
#  ('James B Farnsworth Elementary School', 'Weak'),
#  ('James B McPherson Elementary School', 'Weak'),
#  ('James E McDade Elementary Classical School', 'Weak'),
#  ('James G Blaine Elementary School', 'Weak'),
#  ('James Hedges Elementary School', 'Weak'),
#  ('James Madison Elementary School', 'Weak'),
#  ('James Monroe Elementary School', 'Weak'),
#  ('James N Thorp Elementary School', 'Weak'),
#  ('James Otis Elementary School', 'Weak'),
#  ('James R Doolittle Jr Elementary School', 'Weak'),
#  ('James Russell Lowell Elementary School', 'Weak'),
#  ('James Shields Elementary School', 'Weak'),
#  ('James Wadsworth Elementary School', 'Weak'),
#  ('James Ward Elementary School', 'Weak'),
#  ('James Weldon Johnson Elementary School', 'Weak'),
#  ('Jane Addams Elementary School', 'Weak'),
#  ('Jane A Neil Elementary School', 'Weak'),
#  ('Jean Baptiste Beaubien Elementary School', 'Weak'),
#  ('Jean D Lafayette Elementary School', 'Weak'),
#  ('Jensen Elementary Scholastic Academy', 'Weak'),
#  ('Jesse Owens Elementary Community Academy', 'Weak'),
#  ('Jesse Sherwood Elementary School', 'Weak'),
#  ('Johann W von Goethe Elementary School', 'Weak'),
#  ('John A Walsh Elementary School', 'Weak'),
#  ('John Barry Elementary School', 'Weak'),
#  ('John B Drake Elementary School', 'Weak'),
#  ('John B Murphy Elementary School', 'Weak'),
#  ('John Calhoun North Elementary School', 'Weak'),
#  ('John C Burroughs Elementary School', 'Weak'),
#  ('John C Coonley Elementary School', 'Weak'),
#  ('John C Dore Elementary School', 'Weak'),
#  ('John Charles Haines Elementary School', 'Weak'),
#  ('John D Shoop Math-Science Technical Academy Elementary School', 'Weak'),
#  ('John F Eberhart Elementary School', 'Weak'),
#  ('John Fiske Elementary School', 'Weak'),
#  ('John F Kennedy High School', 'Weak'),
#  ('John Foster Dulles Elementary School', 'Weak'),
#  ('John Greenleaf Whittier Elementary School', 'Weak'),
#  ('John Hancock College Preparatory High School', 'Weak'),
#  ('John Harvard Elementary School of Excellence', 'Weak'),
#  ('John Hay Elementary Community Academy', 'Weak'),
#  ('John H Hamline Elementary School', 'Weak'),
#  ('John H Kinzie Elementary School', 'Weak'),
#  ('John H Vanderpoel Elementary Magnet School', 'Weak'),
#  ('John J Audubon Elementary School', 'Weak'),
#  ('John J Pershing Elementary Humanities Magnet', 'Weak'),
#  ('John L Marsh Elementary School', 'Weak'),
#  ('John Marshall Metropolitan High School', 'Weak'),
#  ('John M Harlan Community Academy High School', 'Weak'),
#  ('John Milton Gregory Elementary School', 'Weak'),
#  ('John M Smyth Elementary School', 'Weak'),
#  ('Johnnie Colemon Elementary Academy', 'Weak'),
#  ('John Palmer Elementary School', 'Weak'),
#  ('John P Altgeld Elementary School', 'Weak'),
#  ('John Spry Elementary Community School', 'Weak'),
#  ('John T McCutcheon Elementary School', 'Weak'),
#  ('John T Pirie Fine Arts & Academic Center Elementary School', 'Weak'),
#  ('John W Cook Elementary School', 'Weak'),
#  ('John W Garvy Elementary School', 'Weak'),
#  ('John Whistler Elementary School', 'Weak'),
#  ('Jonathan Burr Elementary School', 'Weak'),
#  ('Jonathan Y Scammon Elementary School', 'Weak'),
#  ('Jordan Elementary Community School', 'Weak'),
#  ('Jose De Diego Elementary Community Academy', 'Weak'),
#  ('Josefa Ortiz De Dominguez Elementary School', 'Weak'),
#  ('Joseph Brennemann Elementary School', 'Weak'),
#  ('Joseph E Gary Elementary School', 'Weak'),
#  ('Josephine C Locke Elementary School', 'Weak'),
#  ('Joseph Jungman Elementary School', 'Weak'),
#  ('Joseph Kellman Corporate Community Elementary School', 'Weak'),
#  ('Joseph Lovett Elementary School', 'Weak'),
#  ('Joseph Stockton Elementary School', 'Weak'),
#  ('Joseph Warren Elementary School', 'Weak'),
#  ('Joshua D Kershaw Elementary School', 'Weak'),
#  ('Josiah Pickard Elementary School', 'Weak'),
#  ('Joyce Kilmer Elementary School', 'Weak'),
#  ('Julia C Lathrop Elementary School', 'Weak'),
#  ('Julia Ward Howe Elementary School of Excellence', 'Weak'),
#  ('Kate S Buckingham Special Education Center', 'Weak'),
#  ('Kate S Kellogg Elementary School', 'Weak'),
#  ('Kelvyn Park High School', 'Weak'),
#  ('Kenwood Academy High School', 'Weak'),
#  ('Lake View High School', 'Weak'),
#  ('Langston Hughes Elementary School', 'Weak'),
#  ('LaSalle Elementary Language Academy', 'Weak'),
#  ('LaSalle II Magnet Elementary School', 'Weak'),
#  ('Laughlin Falconer Elementary School', 'Weak'),
#  ('Laura S Ward Elementary School', 'Weak'),
#  ('Lawndale Elementary Community Academy', 'Weak'),
#  ('Lazaro Cardenas Elementary School', 'Weak'),
#  ('Leif Ericson Elementary Scholastic Academy', 'Weak'),
#  ('Lenart Elementary Regional Gifted Center', 'Weak'),
#  ('Leslie Lewis Elementary School', 'Weak'),
#  ('Lincoln Park High School', 'Weak'),
#  ('Lionel Hampton Fine & Performing Arts Elementary School', 'Weak'),
#  ('Little Village Elementary School', 'Weak'),
#  ('Logandale Middle School', 'Weak'),
#  ('Lorenz Brentano Math & Science Academy Elementary School', 'Weak'),
#  ('Louis A Agassiz Elementary School', 'Weak'),
#  ('Louisa May Alcott Elementary School', 'Weak'),
#  ('Louis Armstrong Math & Science Elementary School', 'Weak'),
#  ('Louis Nettelhorst Elementary School', 'Weak'),
#  ('Louis Pasteur Elementary School', 'Weak'),
#  ('Ludwig Van Beethoven Elementary School', 'Weak'),
#  ("Luke O'Toole Elementary School", 'Weak'),
#  ('Luther Burbank Elementary School', 'Weak'),
#  ('Lyman A Budlong Elementary School', 'Weak'),
#  ('Lyman Trumbull Elementary School', 'Weak'),
#  ('Mahalia Jackson Elementary School', 'Weak'),
#  ('Mancel Talcott Elementary School', 'Weak'),
#  ('Manley Career Academy High School', 'Weak'),
#  ('Manuel Perez Elementary School', 'Weak'),
#  ('Marcus Moziah Garvey Elementary School', 'Weak'),
#  ('Mariano Azuela Elementary School', 'Weak'),
#  ('Maria Saucedo Elementary Scholastic Academy', 'Weak'),
#  ('Marie Sklodowska Curie Metropolitan High School', 'Weak'),
#  ('Marine Military Math and Science Academy', 'Weak'),
#  ('Mark Sheridan Elementary Math & Science Academy', 'Weak'),
#  ('Mark Skinner Elementary School', 'Weak'),
#  ('Mark Twain Elementary School', 'Weak'),
#  ('Marquette Elementary School', 'Weak'),
#  ('Martha Ruggles Elementary School', 'Weak'),
#  ('Martin A Ryerson Elementary School', 'Weak'),
#  ('Marvin Camras Elementary School', 'Weak'),
#  ('Mary E Courtenay Elementary Language Arts Center', 'Weak'),
#  ('Mary E McDowell Elementary School', 'Weak'),
#  ('Mary Gage Peterson Elementary School', 'Weak'),
#  ('Mary Lyon Elementary School', 'Weak'),
#  ('Mary Mapes Dodge Elementary Renaissance Academy', 'Weak'),
#  ('Mary McLeod Bethune Elementary School', 'Weak'),
#  ('Mason High School', 'Weak'),
#  ('Matthew A Henson Elementary School', 'Weak'),
#  ('Matthew Gallistel Elementary Language Academy', 'Weak'),
#  ('Medgar Evers Elementary School', 'Weak'),
#  ('Melville W Fuller Elementary School', 'Weak'),
#  ('Michael Faraday Elementary School', 'Weak'),
#  ('Michael M Byrne Elementary School', 'Weak'),
#  ('Michele Clark Academic Prep Magnet High School', 'Weak'),
#  ('Mildred I Lavizzo Elementary School', 'Weak'),
#  ('Milton Brunson Math & Science Specialty Elementary School', 'Weak'),
#  ('Minnie Mars Jamieson Elementary School', 'Weak'),
#  ('Miriam G Canter Middle School', 'Weak'),
#  ('Morgan Park High School', 'Weak'),
#  ('Morton School of Excellence', 'Weak'),
#  ('Moses Montefiore Special Elementary School', 'Weak'),
#  ('Mount Greenwood Elementary School', 'Weak'),
#  ('Mount Vernon Elementary School', 'Weak'),
#  ('Multicultural Academy of Scholarship', 'Weak'),
#  ('Myra Bradwell Communications Arts & Sciences Elementary School', 'Weak'),
#  ('Nathanael Greene Elementary School', 'Weak'),
#  ('Nathan Hale Elementary School', 'Weak'),
#  ('Nathaniel Pope Elementary School', 'Weak'),
#  ('Nathan R Goldblatt Elementary School', 'Weak'),
#  ('Nathan S Davis Elementary School', 'Weak'),
#  ('National Teachers Elementary Academy', 'Weak'),
#  ('Neal F Simeon Career Academy High School', 'Weak'),
#  ('Near North Elementary School', 'Weak'),
#  ('New Field Elementary School', 'Weak'),
#  ('New Millennium High School of Health at Bowen', 'Weak'),
#  ('Newton Bateman Elementary School', 'Weak'),
#  ('Nicholas Senn High School', 'Weak'),
#  ('Nicholson Technology Academy', 'Weak'),
#  ('Ninos Heroes Elementary Academic Center', 'Weak'),
#  ('Norman A Bridge Elementary School', 'Weak'),
#  ('North-Grand High School', 'Weak'),
#  ('North River Elementary School', 'Weak'),
#  ('Northside College Preparatory High School', 'Weak'),
#  ('Percy L Julian High School', 'Weak'),
#  ('Northside Learning Center High School', 'Weak'),
#  ('Northwest Middle School', 'Weak'),
#  ('Norwood Park Elementary School', 'Weak'),
#  ('Ogden International High School', 'Weak'),
#  ('Ole A Thorp Elementary Scholastic Academy', 'Weak'),
#  ('Oliver S Westcott Elementary School', 'Weak'),
#  ('Oliver Wendell Holmes Elementary School', 'Weak'),
#  ('Oriole Park Elementary School', 'Weak'),
#  ('Orozco Fine Arts & Sciences Elementary School', 'Weak'),
#  ('Orr Academy High School', 'Weak'),
#  ('Orville T Bright Elementary School', 'Weak'),
#  ('Oscar DePriest Elementary School', 'Weak'),
#  ('Oscar F Mayer Elementary School', 'Weak'),
#  ('Pablo Casals Elementary School', 'Weak'),
#  ('Park Manor Elementary School', 'Weak'),
#  ('Parkside Elementary Community Academy', 'Weak'),
#  ('Patrick Henry Elementary School', 'Weak'),
#  ('Paul Cuffe Math-Science Technology Academy Elementary School', 'Weak'),
#  ('Paul Laurence Dunbar Career Academy High School', 'Weak'),
#  ('Paul Revere Elementary School', 'Weak'),
#  ('Paul Robeson High School', 'Weak'),
#  ('Perkins Bass Elementary School', 'Weak'),
#  ('Pershing West Middle School', 'Weak'),
#  ('Peter A Reinberg Elementary School', 'Weak'),
#  ('Peter Cooper Elementary Dual Language Academy', 'Weak'),
#  ('Philip Rogers Elementary School', 'Weak'),
#  ('Phillip D Armour Elementary School', 'Weak'),
#  ('Phillip Murray Elementary Language Academy', 'Weak'),
#  ('Phobe Apperson Hearst Elementary School', 'Weak'),
#  ('Phoenix Military Academy High School', 'Weak'),
#  ('Pilsen Elementary Community Academy', 'Weak'),
#  ('Portage Park Elementary School', 'Weak'),
#  ('Pulaski International Academy Elmentary School', 'Weak'),
#  ('Rachel Carson Elementary School', 'Weak'),
#  ('Ralph H Metcalfe Elementary Community Academy', 'Weak'),
#  ('Ravenswood Elementary School', 'Weak'),
#  ('Ray Graham Training Center High School', 'Weak'),
#  ('Richard Edwards Elementary School', 'Weak'),
#  ('Richard Henry Lee Elementary School', 'Weak'),
#  ('Richard J Daley Elementary Academy', 'Weak'),
#  ('Richard J Oglesby Elementary School', 'Weak'),
#  ('Richard T Crane Technical Preparatory High School', 'Weak'),
#  ('Richard Yates Elementary School', 'Weak'),
#  ('Roald Amundsen High School', 'Weak'),
#  ('Robert A Black Magnet Elementary School', 'Weak'),
#  ('Robert Emmet Elementary School', 'Weak'),
#  ('Robert Fulton Elementary School', 'Weak'),
#  ('Robert Healy Elementary School', 'Weak'),
#  ('Robert H Lawrence Elementary School', 'Weak'),
#  ('Robert L Grimes Elementary School', 'Weak'),
#  ('Robert Lindblom Math & Science Academy High School', 'Weak'),
#  ('Robert Nathaniel Dett Elementary School', 'Weak'),
#  ('Roberto Clemente Community Academy High School', 'Weak'),
#  ('Rodolfo Lozano Bilingual & International Center Elementary School', 'Weak'),
#  ('Roger C Sullivan High School', 'Weak'),
#  ('Ronald Brown Elementary Community Academy', 'Weak'),
#  ('Ronald E McNair Elementary School', 'Weak'),
#  ('Rosario Castellanos Elementary School', 'Weak'),
#  ('Roswell B Mason Elementary School', 'Weak'),
#  ('Rudyard Kipling Elementary School', 'Weak'),
#  ('Rueben Salazar Elementary Bilingual Center', 'Weak'),
#  ('Rufus M Hitch Elementary School', 'Weak'),
#  ('Salmon P Chase Elementary School', 'Weak'),
#  ('Samuel Gompers Fine Arts Options Elementary School', 'Weak'),
#  ('Sauganash Elementary School', 'Weak'),
#  ('Scott Joplin Elementary School', 'Weak'),
#  ('Sharon Christa McAuliffe Elementary School', 'Weak'),
#  ('Sidney Sawyer Elementary School', 'Weak'),
#  ('Simon Guggenheim Elementary School', 'Weak'),
#  ('Sir Miles Davis Magnet Elementary Academy', 'Weak'),
#  ('Skinner North', 'Weak'),
#  ('Socorro Sandoval Elementary School', 'Weak'),
#  ('Songhai Elementary Learning Institute', 'Weak'),
#  ('South Loop Elementary School', 'Weak'),
#  ('South Shore Fine Arts Academy', 'Weak'),
#  ('Southside Occupational Academy High School', 'Weak'),
#  ('Spencer Technology Academy', 'Weak'),
#  ('Spry Community Links High School', 'Weak'),
#  ('Stephen Decatur Classical Elementary School', 'Weak'),
#  ('Stephen F Gale Elementary Community Academy', 'Weak'),
#  ('Stephen K Hayt Elementary School', 'Weak'),
#  ('Stephen T Mather High School', 'Weak'),
#  ('Stone Elementary Scholastic Academy', 'Weak'),
#  ('Suder Montessori Magnet Elementary School', 'Weak'),
#  ('Talman Elementary School', 'Weak'),
#  ('Tarkington School of Excellence Elementary School', 'Weak'),
#  ('TEAM Englewood Community Academy High School', 'Weak'),
#  ('Telpochcalli Elementary School', 'Weak'),
#  ('Theodore Herzl Elementary School', 'Weak'),
#  ('Theodore Roosevelt High School', 'Weak'),
#  ('Theophilus Schmid Elementary School', 'Weak'),
#  ('Thomas A Edison Regional Gifted Center Elementary School', 'Weak'),
#  ('Thomas A Hendricks Elementary Community Academy', 'Weak'),
#  ('Thomas Chalmers Specialty Elementary School', 'Weak'),
#  ('Thomas Drummond Elementary School', 'Weak'),
#  ('Thomas Hoyne Elementary School', 'Weak'),
#  ('Thomas J Higgins Elementary Community Academy', 'Weak'),
#  ('Thomas J Waters Elementary School', 'Weak'),
#  ('Thomas Kelly High School', 'Weak'),
#  ('Thurgood Marshall Middle School', 'Weak'),
#  ('Turner-Drew Elementary Language Academy', 'Weak'),
#  ('Uplift Community High School', 'Weak'),
#  ('Velma F Thomas Early Childhood Center', 'Weak'),
#  ('Victor Herbert Elementary School', 'Weak'),
#  ('Virgil Grissom Elementary School', 'Weak'),
#  ('VOISE Academy High School', 'Weak'),
#  ('Walt Disney Magnet Elementary School', 'Weak'),
#  ('Walter L Newberry Math & Science Academy Elementary School', 'Weak'),
#  ('Walter Payton College Preparatory High School', 'Weak'),
#  ('Walter Q Gresham Elementary School', 'Weak'),
#  ('Walter Reed Elementary School', 'Weak'),
#  ('Walter S Christopher Elementary School', 'Weak'),
#  ('Washington D Smyser Elementary School', 'Weak'),
#  ('Washington Irving Elementary School', 'Weak'),
#  ('Wells Community Academy High School', 'Weak'),
#  ('Wendell E Green Elementary School', 'Weak'),
#  ('Wendell Phillips Academy High School', 'Weak'),
#  ('Wendell Smith Elementary School', 'Weak'),
#  ('West Park Elementary Academy', 'Weak'),
#  ('West Pullman Elementary School', 'Weak'),
#  ('West Ridge Elementary School', 'Weak'),
#  ('Whitney M Young Magnet High School', 'Weak'),
#  ('Wildwood Elementary School', 'Weak'),
#  ('Willa Cather Elementary School', 'Weak'),
#  ('William A Hinton Elementary School', 'Weak'),
#  ('William Bishop Owen Scholastic Academy Elementary School', 'Weak'),
#  ('William B Ogden Elementary School', 'Weak'),
#  ('William C Goudy Elementary School', 'Weak'),
#  ('William C Reavis Math & Science Specialty Elementary School', 'Weak'),
#  ('William E B Dubois Elementary School', 'Weak'),
#  ('William E Dever Elementary School', 'Weak'),
#  ('William F Finkl Elementary School', 'Weak'),
#  ('William G Hibbard Elementary School', 'Weak'),
#  ('William H Brown Elementary School', 'Weak'),
#  ('William H King Elementary School', 'Weak'),
#  ('William Howard Taft High School', 'Weak'),
#  ('William H Prescott Elementary School', 'Weak'),
#  ('William H Ray Elementary School', 'Weak'),
#  ('William H Ryder Math & Science Specialty Elementary School', 'Weak'),
#  ('William H Seward Communication Arts Academy Elementary School', 'Weak'),
#  ('William J Bogan High School', 'Weak'),
#  ('William J & Charles H Mayo Elementary School', 'Weak'),
#  ('William J Onahan Elementary School', 'Weak'),
#  ('William Jones College Preparatory High School', 'Weak'),
#  ('William K New Sullivan Elementary School', 'Weak'),
#  ('William Penn Elementary School', 'Weak'),
#  ('William P Gray Elementary School', 'Weak'),
#  ('William P Nixon Elementary School', 'Weak'),
#  ('William Rainey Harper High School', 'Weak'),
#  ('Williams Multiplex Elementary School', 'Weak'),
#  ('Williams Preparatory Academy Middle School', 'Weak'),
#  ('William T Sherman Elementary School', 'Weak'),
#  ('William W Carter Elementary School', 'Weak'),
#  ('Wolfgang A Mozart Elementary School', 'Weak'),
#  ('Woodlawn Community Elementary School', 'Weak'),
#  ('World Language Academy High School', 'Weak')]

# %%
# %%sql CREATE PROCEDURE UPDATE_LEADERS_SCORE	-- NAME OF THIS STORED PROCEDURE ROUTING
# (IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADER_SCORE INTEGER)
#
# LANGUAGE SQL                                       -- LANGUAGE USED IN THIS ROUTINE
# READS SQL DATA                                     -- THIS ROUTINE WILL ONLY READ DATA FROM THE TABLE
#
# DYNAMIC RESULT SETS 1                              -- MAXIMUM POSSIBLE NUMBER OF RESULT-SETS TO BE RETURNED TO THE CALLER QUERY
#
# BEGIN                                              --
#
# 	DECLARE C1 CURSOR                              -- CURSOR C1 WILL HANDLE THE RESULT SET BY RETRIEVING RECORDS ROW BY ROW FROM THE TABLE
# 	WITH RETURN FOR                                -- THIS ROUTINE WILL RETURN RETRIEVED RECORDS AS A RESULT SET TO THE CALLER QUERY
#
# 	SELECT * FROM CHICAGO_PUBLIC_SCHOOLS;          -- QUERY TO RETRIEVE ALL THE RECORDS FROM THE TABLE
#
# 	OPEN C1;                                        -- KEEPING THE CURSOR C1 OPEN SO THAT RESULT SET CAN BE RETURNED TO THE CALLER QUERY
# END
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "PROCEDURE": syntax error
# [SQL: CREATE PROCEDURE UPDATE_LEADERS_SCORE
# (IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADER_SCORE INTEGER)
#
# LANGUAGE SQL                                       -- LANGUAGE USED IN THIS ROUTINE
# READS SQL DATA                                     -- THIS ROUTINE WILL ONLY READ DATA FROM THE TABLE
#
# DYNAMIC RESULT SETS 1                              -- MAXIMUM POSSIBLE NUMBER OF RESULT-SETS TO BE RETURNED TO THE CALLER QUERY
#
# BEGIN                                              --
#
# 	DECLARE C1 CURSOR                              -- CURSOR C1 WILL HANDLE THE RESULT SET BY RETRIEVING RECORDS ROW BY ROW FROM THE TABLE
# 	WITH RETURN FOR                                -- THIS ROUTINE WILL RETURN RETRIEVED RECORDS AS A RESULT SET TO THE CALLER QUERY
#
# 	SELECT * FROM CHICAGO_PUBLIC_SCHOOLS;          -- QUERY TO RETRIEVE ALL THE RECORDS FROM THE TABLE
#
# 	OPEN C1;                                        -- KEEPING THE CURSOR C1 OPEN SO THAT RESULT SET CAN BE RETURNED TO THE CALLER QUERY
# END]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql SCREATE PROCEDURE UPDATE_LEADERS_SCORE             -- NAME OF THIS STORED PROCEDURE ROUTINE
# (IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADERS_SCORE INTEGER)
#
# LANGUAGE SQL                                       --
# MODIFIES SQL DATA
#
# BEGIN
#
# UPDATE "CHICAGO_PUBLIC_SCHOOLS"
# SET "LEADERS_SCORE" = IN_LEADERS_SCORE
# WHERE "SCHOOL_ID" = IN_SCHOOL_ID;
#
# END
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "SCREATE": syntax error
# [SQL: SCREATE PROCEDURE UPDATE_LEADERS_SCORE
# (IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADERS_SCORE INTEGER)
#
# LANGUAGE SQL                                       --
# MODIFIES SQL DATA
#
# BEGIN
#
# UPDATE "CHICAGO_PUBLIC_SCHOOLS"
# SET "LEADERS_SCORE" = IN_LEADERS_SCORE
# WHERE "SCHOOL_ID" = IN_SCHOOL_ID;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql SET TERMINATOR @
# CREATE OR REPLACE PROCEDURE UPDATE_LEADERS_SCORE(
# IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADER_SCORE INTEGER)
#
# LANGUAGE SQL
# MODIFIES SQL DATA
#
# BEGIN
#
# 	UPDATE CHICAGO_PUBLIC_SCHOOLS
#
# 	SET "LEADERS_SCORE" = IN_LEADER_SCORE
# 	WHERE "SCHOOL_ID" = IN_SCHOOL_ID;
#
# 	IF IN_LEADER_SCORE > 0 AND IN_LEADER_SCORE < 20 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON"='VERY WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 40 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 60 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'AVERAGE';
#
# 	ELSEIF IN_LEADER_SCORE < 80 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'STRONG';
#
# 	ELSEIF IN_LEADER_SCORE < 100 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'VERY STRONG';
# 	END IF;
# END
# @
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "SET": syntax error
# [SQL: SET TERMINATOR @
# CREATE OR REPLACE PROCEDURE UPDATE_LEADERS_SCORE(
# IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADER_SCORE INTEGER)
#
# LANGUAGE SQL
# MODIFIES SQL DATA
#
# BEGIN
#
# 	UPDATE CHICAGO_PUBLIC_SCHOOLS
#
# 	SET "LEADERS_SCORE" = IN_LEADER_SCORE
# 	WHERE "SCHOOL_ID" = IN_SCHOOL_ID;
#
# 	IF IN_LEADER_SCORE > 0 AND IN_LEADER_SCORE < 20 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON"='VERY WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 40 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 60 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'AVERAGE';
#
# 	ELSEIF IN_LEADER_SCORE < 80 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'STRONG';
#
# 	ELSEIF IN_LEADER_SCORE < 100 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'VERY STRONG';
# 	END IF;
# END
# @]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql CALL UPDATE_LEADERS_SCORE()
# Out:
# UsageError: %%sql is a cell magic, but the cell body is empty. Did you mean the line magic %sql (single %)?

# %%
# %%sql SET TERMINATOR @
# CREATE OR REPLACE PROCEDURE UPDATE_LEADERS_SCORE(
# IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADER_SCORE INTEGER)
#
# LANGUAGE SQL
# MODIFIES SQL DATA
#
# BEGIN
#
# 	UPDATE CHICAGO_PUBLIC_SCHOOLS
#
# 	SET "LEADERS_SCORE" = IN_LEADER_SCORE
# 	WHERE "SCHOOL_ID" = IN_SCHOOL_ID;
#
# 	IF IN_LEADER_SCORE > 0 AND IN_LEADER_SCORE < 20 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON"='VERY WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 40 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 60 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'AVERAGE';
#
# 	ELSEIF IN_LEADER_SCORE < 80 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'STRONG';
#
# 	ELSEIF IN_LEADER_SCORE < 100 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'VERY STRONG';
#
# 	ELSE
# 		ROLLBACK WORK;
# 	END IF;
# 		COMMIT WORK;
# END
# @
# Out:
#  * sqlite:///FinalDB.db
# (sqlite3.OperationalError) near "SET": syntax error
# [SQL: SET TERMINATOR @
# CREATE OR REPLACE PROCEDURE UPDATE_LEADERS_SCORE(
# IN IN_SCHOOL_ID INTEGER,
# IN IN_LEADER_SCORE INTEGER)
#
# LANGUAGE SQL
# MODIFIES SQL DATA
#
# BEGIN
#
# 	UPDATE CHICAGO_PUBLIC_SCHOOLS
#
# 	SET "LEADERS_SCORE" = IN_LEADER_SCORE
# 	WHERE "SCHOOL_ID" = IN_SCHOOL_ID;
#
# 	IF IN_LEADER_SCORE > 0 AND IN_LEADER_SCORE < 20 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON"='VERY WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 40 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'WEAK';
#
# 	ELSEIF IN_LEADER_SCORE < 60 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'AVERAGE';
#
# 	ELSEIF IN_LEADER_SCORE < 80 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'STRONG';
#
# 	ELSEIF IN_LEADER_SCORE < 100 THEN
# 		UPDATE CHICAGO_PUBLIC_SCHOOLS
# 		SET "LEADERS_ICON" = 'VERY STRONG';
#
# 	ELSE
# 		ROLLBACK WORK;
# 	END IF;
# 		COMMIT WORK;
# END
# @]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql CALL UPDATE_LEADERS_SCORE(610038,45);
# Out:
# UsageError: %%sql is a cell magic, but the cell body is empty. Did you mean the line magic %sql (single %)?

# %%
# %%sql CALL UPDATE_LEADERS_SCORE(610038,101)
# Out:
# UsageError: %%sql is a cell magic, but the cell body is empty. Did you mean the line magic %sql (single %)?

# %% [markdown]
# Copyright © 2020 This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork20127838-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2022-03-04 | 2.5     | Lakshmi Holla     | Changed markdown.                   |
# | 2021-05-19 | 2.4     | Lakshmi Holla     | Updated the question                           |
# | 2021-04-30 | 2.3     | Malika Singla     | Updated the libraries                          |
# | 2021-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
